# %%
pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.6/914.6 kB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip "/content/Dog Breed Dataset.zip"
# Out:
# Archive:  /content/Dog Breed Dataset.zip
#    creating: Dog Breed Dataset/test/
#    creating: Dog Breed Dataset/test/Beagle/
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_15.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_16.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_31.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_32.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_47.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_48.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_63.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_64.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_79.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_80.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_95.jpg
#   inflating: Dog Breed Dataset/test/Beagle/Beagle_96.jpg
#    creating: Dog Breed Dataset/test/Boxer/
#   inflating: Dog Breed Dataset/test/Boxer/Boxer_15.jpg
#   inflating: Dog Breed Dataset/test/Boxer/Boxer_16.jpg
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.9/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
model = YOLO('yolo11m-cls.pt')

#train the model
results = model.train(data='/content/Dog Breed Dataset', epochs=15, imgsz=640)
# Out:
# ...
# 100%|██████████| 22.4M/22.4M [00:00<00:00, 68.6MB/s]
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
Image("/content/runs/classify/train/results.png", width=600)

# %%
# !yolo classify predict model="/content/runs/classify/train/weights/best.pt" source="/content/Dog Breed Dataset/test/Boxer/Boxer_32.jpg" save=True conf=0.5
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m-cls summary (fused): 138 layers, 10,354,442 parameters, 0 gradients, 39.3 GFLOPs
#
# image 1/1 /content/Dog Breed Dataset/test/Boxer/Boxer_32.jpg: 640x640 Boxer 1.00, Bulldog 0.00, Rottweiler 0.00, German_Shepherd 0.00, Poodle 0.00, 20.7ms
# Speed: 41.9ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image("/content/runs/classify/predict3/Boxer_32.jpg")
